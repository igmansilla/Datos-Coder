# %%
import matplotlib.pyplot as plt

import numpy as np

import pandas as pd

import seaborn as sns

url = 'https://raw.githubusercontent.com/igmansilla/Datos-Coder/main/df_limpio.csv'

df = pd.read_csv(url)

# %%
df.head()
# Out:
#    Unnamed: 0              country  year      status  life_expectancy  \
# 0           0          Afghanistan  2015  Developing             65.0
# 1          16              Albania  2015  Developing             77.8
# 2          32              Algeria  2015  Developing             75.6
# 3          48               Angola  2015  Developing             52.4
# 4          64  Antigua and Barbuda  2015  Developing             76.4
#
#    adult_mortality  infant_deaths   alcohol  percentage_expenditure  \
# 0            263.0      62.000000  0.010000               71.279624
# 1             74.0      35.129032  4.600000              364.975229
# 2             19.0      21.000000  5.288333                0.000000
# 3            335.0      66.000000  5.288333                0.000000
# 4             13.0      35.129032  5.288333                0.000000
#
#    hepatitis_b  ...  polio  total_expenditure  diphtheria  hiv/aids  \
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0         year  life_expectancy  adult_mortality  \
# count  2938.000000  2938.000000      2938.000000      2938.000000
# mean   1468.500000  2007.518720        69.231777       172.924761
# std     848.271871     4.613841         9.508362       118.847313
# min       0.000000  2000.000000        36.300000        13.000000
# 25%     734.250000  2004.000000        63.200000        84.000000
# 50%    1468.500000  2008.000000        72.000000       157.000000
# 75%    2202.750000  2012.000000        75.600000       227.000000
# max    2937.000000  2015.000000        89.000000       723.000000
#
#        infant_deaths      alcohol  percentage_expenditure  hepatitis_b  \
# count    2938.000000  2938.000000             2938.000000  2938.000000
# mean       42.458242     4.644013              738.251295    80.322757
# std       116.366814     3.919849             1987.914858    22.682329
# min         1.000000     0.010000                0.000000     1.000000
# ...

# %% [markdown]
# ## Histogramas

# %%
cont_vars = list(df.columns)[3:]
plt.figure(figsize=(15, 20))
for i, col in enumerate(cont_vars, 1):
    plt.subplot(5, 4, i)
    plt.hist(df[col])
    plt.title(col)

# %% [markdown]
# ### Filas y países

# %%
plt.figure(figsize=(15, 25))
df.country.value_counts(ascending=True).plot(kind='barh')
plt.title('Cantidad de filas por país')
plt.xlabel('Cantidad de filas')
plt.ylabel('Pais')
plt.tight_layout()
plt.show()

# %% [markdown]
# El gráafico es desproporcionado pero muestra que hay algunos paises a los que les faltan filas

# %%
df.year.value_counts().sort_index().plot(kind='barh')
plt.title('Cantidad de filas por año')
plt.xlabel('Cantidad de filas')
plt.ylabel('Año')
plt.show()

# %% [markdown]
# El año 2013 tiene algunos registros de más

# %%
plt.figure(figsize=(10, 5))
plt.subplot(121)
df.status.value_counts().plot(kind='bar')
plt.title('Cantidad de filas por estado del pais')
plt.xlabel('Estado del país')
plt.ylabel('Cantidad de filas')
plt.xticks(rotation=0)

plt.subplot(122)
df.status.value_counts().plot(kind='pie', autopct='%.2f')
plt.ylabel('')
plt.title('Estado del país. Gráfico de torta')

plt.show()

# %% [markdown]
# La mayor parte de nuestros datos proceden de países clasificados como "en desarrollo"(developing): el 82,57% para ser exactos. Esto dificulta el uso de modelos predictivos porque hya un sesgo en la cantidad de datos de un valor y otro. Es probable que cualquier modelo que se utilice represente con mayor, ya que la mayoría de los datos se encuentran en países "en desarrollo" y no en países "desarrollados".
